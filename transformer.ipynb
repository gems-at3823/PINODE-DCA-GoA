# %% [markdown]
# Number of heads = 2

# %%
from ensembled_transformer import main
# %matplotlib inline
# Out:
# <script src='https://cdn.jsdelivr.net/npm/@widgetti/styler'></script>

# %%
main()
# Out:
# Main function started with Exponential Decline
# [DEBUG] load_and_process_data started
# [DEBUG] Data processed
# [DEBUG] Decomposition results obtained
# [DEBUG] Trend and residuals processed
# C:\Users\axt43242\Downloads\Sands\1999sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2001sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2003sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2004sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2005sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2006sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2007sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2008sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2009 Atlas Update.xlsx already exists. Skipping conversion.
# ...

# %% [markdown]
# Number of heads = 8

# %%
from ensembled_transformer import main
# %matplotlib inline

# %%
main()
# Out:
# Main function started with Exponential Decline
# [DEBUG] load_and_process_data started
# [DEBUG] Data processed
# [DEBUG] Decomposition results obtained
# [DEBUG] Trend and residuals processed
# C:\Users\axt43242\Downloads\Sands\1999sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2001sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2003sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2004sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2005sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2006sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2007sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2008sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2009 Atlas Update.xlsx already exists. Skipping conversion.
# ...

# %% [markdown]
# Number of heads = 16

# %%
from ensembled_transformer import main
# %matplotlib inline

# %%
main()
# Out:
# Main function started with Exponential Decline
# [DEBUG] load_and_process_data started
# [DEBUG] Data processed
# [DEBUG] Decomposition results obtained
# [DEBUG] Trend and residuals processed
# C:\Users\axt43242\Downloads\Sands\1999sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2001sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2003sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2004sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2005sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2006sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2007sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2008sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2009 Atlas Update.xlsx already exists. Skipping conversion.
# ...

# %% [markdown]
# Single Layer Transformer

# %%
from ensembled_transformer import main
# %matplotlib inline
# Out:
# <script src='https://cdn.jsdelivr.net/npm/@widgetti/styler'></script>

# %%
main()
# Out:
# Main function started with Exponential Decline
# [DEBUG] load_and_process_data started
# [DEBUG] Data processed
# [DEBUG] Decomposition results obtained
# [DEBUG] Trend and residuals processed
# C:\Users\axt43242\Downloads\Sands\1999sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2001sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2003sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2004sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2005sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2006sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2007sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2008sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2009 Atlas Update.xlsx already exists. Skipping conversion.
# ...

# %% [markdown]
# Two Layer 128, 64

# %%
from ensembled_transformer import main
# %matplotlib inline

# %%
main()
# Out:
# Main function started with Exponential Decline
# [DEBUG] load_and_process_data started
# [DEBUG] Data processed
# [DEBUG] Decomposition results obtained
# [DEBUG] Trend and residuals processed
# C:\Users\axt43242\Downloads\Sands\1999sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2001sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2003sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2004sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2005sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2006sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2007sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2008sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2009 Atlas Update.xlsx already exists. Skipping conversion.
# ...

# %% [markdown]
# four layers 128, 64, 32, 16

# %%
from ensembled_transformer import main
# %matplotlib inline
# Out:
# <script src='https://cdn.jsdelivr.net/npm/@widgetti/styler'></script>

# %%
main()
# Out:
# Main function started with Exponential Decline
# [DEBUG] load_and_process_data started
# [DEBUG] Data processed
# [DEBUG] Decomposition results obtained
# [DEBUG] Trend and residuals processed
# C:\Users\axt43242\Downloads\Sands\1999sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2001sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2003sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2004sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2005sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2006sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2007sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2008sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2009 Atlas Update.xlsx already exists. Skipping conversion.
# ...

# %% [markdown]
# embed_dim=64 (leads to better fit if underfitting)

# %%
from ensembled_transformer import main
# %matplotlib inline

# %%
main()
# Out:
# Main function started with Exponential Decline
# [DEBUG] load_and_process_data started
# [DEBUG] Data processed
# [DEBUG] Decomposition results obtained
# [DEBUG] Trend and residuals processed
# C:\Users\axt43242\Downloads\Sands\1999sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2001sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2003sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2004sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2005sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2006sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2007sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2008sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2009 Atlas Update.xlsx already exists. Skipping conversion.
# ...

# %% [markdown]
# embed_dim = 512

# %%
from ensembled_transformer import main
# %matplotlib inline
# Out:
# <script src='https://cdn.jsdelivr.net/npm/@widgetti/styler'></script>

# %%
main()
# Out:
# Main function started with Exponential Decline
# [DEBUG] load_and_process_data started
# [DEBUG] Data processed
# [DEBUG] Decomposition results obtained
# [DEBUG] Trend and residuals processed
# C:\Users\axt43242\Downloads\Sands\1999sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2001sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2003sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2004sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2005sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2006sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2007sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2008sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2009 Atlas Update.xlsx already exists. Skipping conversion.
# ...

# %% [markdown]
# embed_dim = 16, rate = 0.2 (previously 0.1)

# %%
from ensembled_transformer import main
# %matplotlib inline
# Out:
# <script src='https://cdn.jsdelivr.net/npm/@widgetti/styler'></script>

# %%
main()
# Out:
# Main function started with Exponential Decline
# [DEBUG] load_and_process_data started
# [DEBUG] Data processed
# [DEBUG] Decomposition results obtained
# [DEBUG] Trend and residuals processed
# C:\Users\axt43242\Downloads\Sands\1999sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2001sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2003sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2004sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2005sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2006sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2007sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2008sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2009 Atlas Update.xlsx already exists. Skipping conversion.
# ...

# %% [markdown]
# best hyper_params: embed_dim = 32, rate = 0.1, four layers: 128, 64, 32, 16, ff_dim: 32

# %% [markdown]
# embed_dim=32, ff_dim=64

# %%
from ensembled_transformer import main
# %matplotlib inline
# Out:
# <script src='https://cdn.jsdelivr.net/npm/@widgetti/styler'></script>

# %%
main()
# Out:
# Main function started with Exponential Decline
# [DEBUG] load_and_process_data started
# [DEBUG] Data processed
# [DEBUG] Decomposition results obtained
# [DEBUG] Trend and residuals processed
# C:\Users\axt43242\Downloads\Sands\1999sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2001sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2003sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2004sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2005sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2006sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2007sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2008sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2009 Atlas Update.xlsx already exists. Skipping conversion.
# ...

# %% [markdown]
# added regularizes l1=l2=0.01; losses: huber; dropout=0.2, 4 layers, embed_dim=32, num_heads=16, ff_dim=64

# %%
from ensembled_transformer import main
# %matplotlib inline

# %%
main()
# Out:
# Main function started with Exponential Decline
# [DEBUG] load_and_process_data started
# [DEBUG] Data processed
# [DEBUG] Decomposition results obtained
# [DEBUG] Trend and residuals processed
# C:\Users\axt43242\Downloads\Sands\1999sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2001sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2003sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2004sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2005sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2006sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2007sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2008sands.xlsx already exists. Skipping conversion.
# C:\Users\axt43242\Downloads\Sands\2009 Atlas Update.xlsx already exists. Skipping conversion.
# ...

# %%
from ensembled_transformer import main
# %matplotlib inline

# %%
main()

# %%
from neural_odes import main
# %matplotlib inline

# %%
main()
# Out:
# Starting main...
# Loading data...
# Data loaded.
# Extracting completion data...
# Found 3440 completions.
# interactive(children=(Dropdown(description='Completion:', options=('AC24 SS001 ST01BP00', 'AC25 HA001 ST00BP00…
# Dropdown(description='Completion:', options=('AC24 SS001 ST01BP00', 'AC25 HA001 ST00BP00', 'AC26 HA002 ST00BP0…

# %%
from node_with_cpd import main
# %matplotlib inline

# %%
main()
# Out:
# Starting main...
# Loading data...
# Data loaded.
# Extracting completion data...
# Found 3440 completions.
# Preprocessing data...
# Data preprocessed.
# t_max: 16, q_max: 7905.666666666667
# Detected change points: [42, 60, 90, 126, 259]
# interactive(children=(Dropdown(description='Completion:', options=('AC24 SS001 ST01BP00', 'AC25 HA001 ST00BP00…
# Dropdown(description='Completion:', options=('AC24 SS001 ST01BP00', 'AC25 HA001 ST00BP00', 'AC26 HA002 ST00BP0…
# IntSlider(value=0, continuous_update=False, description='Change Point:', max=6)

# %%
from node_any_q import main
# %matplotlib inline

# %%
main()
# Out:
# interactive(children=(Dropdown(description='Completion:', options=('AC24 SS001 ST01BP00', 'AC25 HA001 ST00BP00…
# Dropdown(description='Completion:', options=('AC24 SS001 ST01BP00', 'AC25 HA001 ST00BP00', 'AC26 HA002 ST00BP0…
# IntSlider(value=0, continuous_update=False, description='Index:', max=258)
